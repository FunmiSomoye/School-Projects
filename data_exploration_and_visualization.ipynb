# %% [markdown]
# <a href="https://colab.research.google.com/github/FunmiSomoye/School-Projects/blob/master/data_exploration_and_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color='maroon'>Assessment</font>

# %% [markdown]
# The assessment requires you to explore the dataset provided. To gain insights into the data you must produce descriptive statistics and appropriate visualisations. Use the techniques you've learned so far to manipulate the data.

# %%
# necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# The dataset contents simulation data of 8 construction variables and 2 energy efficiency variables (heating and cooling load). The variables are
#
#     X1 Relative Compactness
#     X2 Surface Area
#     X3 Wall Area
#     X4 Roof Area
#     X5 Overall Height
#     X6 Orientation
#     X7 Glazing Area
#     X8 Glazing Area Distribution
#     y1 Heating Load
#     y2 Cooling Load
#
#
# For more information on the dataset see [Energy efficiency Data Set](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency).

# %% [markdown]
# ### Exploring the data

# %% [markdown]
# ** Ouestion 1.** Load the data, display information about the columns, determine how many rows and columns there are, observe any missing values, and provide descriptive statistics. Discuss the statistics and information gleaned from exploring the data.

# %%
# %matplotlib inline

# %% [markdown]
# The Data
# -

# %%
ENB = pd.read_csv('ENB2012_data.csv', #name of file
                   sep=',')  # how columns are separated

# %%
ENB
# Out:
#        X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0    0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1    0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2    0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3    0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4    0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28
# 5    0.90  563.5  318.5  122.50  7.0   3  0.0   0  21.46  25.38
# 6    0.90  563.5  318.5  122.50  7.0   4  0.0   0  20.71  25.16
# 7    0.90  563.5  318.5  122.50  7.0   5  0.0   0  19.68  29.60
# 8    0.86  588.0  294.0  147.00  7.0   2  0.0   0  19.50  27.30
# 9    0.86  588.0  294.0  147.00  7.0   3  0.0   0  19.95  21.97
# 10   0.86  588.0  294.0  147.00  7.0   4  0.0   0  19.34  23.49
# 11   0.86  588.0  294.0  147.00  7.0   5  0.0   0  18.31  27.87
# 12   0.82  612.5  318.5  147.00  7.0   2  0.0   0  17.05  23.77
# 13   0.82  612.5  318.5  147.00  7.0   3  0.0   0  17.41  21.46
# ...

# %% [markdown]
# Rename Columns for better understanding

# %%
ENB2 = ENB.rename(columns={'X1': 'Relative Compactness', 'X2': 'Surface Area', 'X3': 'Wall Area', 'X4': 'Roof Area', 
                           'X5': 'Overall Height', 'X6': 'Orientation', 'X7': 'Glazing Area', 'X8': 'Glazing Area Distribution', 
                           'Y1': 'Heating Load', 'Y2': 'Cooling Load'})  #rename columns and save in new file

# %%
ENB2
# Out:
#      Relative Compactness  Surface Area  Wall Area  Roof Area  Overall Height  \
# 0                    0.98         514.5      294.0     110.25             7.0
# 1                    0.98         514.5      294.0     110.25             7.0
# 2                    0.98         514.5      294.0     110.25             7.0
# 3                    0.98         514.5      294.0     110.25             7.0
# 4                    0.90         563.5      318.5     122.50             7.0
# 5                    0.90         563.5      318.5     122.50             7.0
# 6                    0.90         563.5      318.5     122.50             7.0
# 7                    0.90         563.5      318.5     122.50             7.0
# 8                    0.86         588.0      294.0     147.00             7.0
# 9                    0.86         588.0      294.0     147.00             7.0
# 10                   0.86         588.0      294.0     147.00             7.0
# ...

# %% [markdown]
# “We perform energy analysis using 12 different building shapes simulated in Ecotect (energy building simulation software). The buildings differ with respect to the glazing area, the glazing area distribution, and the orientation, amongst other parameters. We simulate various settings as functions of the afore-mentioned characteristics to obtain 768 building shapes. The dataset comprises 768 samples and 8 features, aiming to predict two real valued responses ...\”.

# %% [markdown]
# Columns
# -

# %%
ENB2.columns #display data about the columns
# Out:
# Index(['Relative Compactness', 'Surface Area', 'Wall Area', 'Roof Area',
#        'Overall Height', 'Orientation', 'Glazing Area',
#        'Glazing Area Distribution', 'Heating Load', 'Cooling Load'],
#       dtype='object')

# %% [markdown]
# Get more detailed info on columns with little observed data variation

# %%
ENB2['Relative Compactness'].unique().tolist()
# Out:
# [0.98, 0.9, 0.86, 0.82, 0.79, 0.76, 0.74, 0.71, 0.69, 0.66, 0.64, 0.62]

# %%
ENB2['Surface Area'].unique().tolist()
# Out:
# [514.5,
#  563.5,
#  588.0,
#  612.5,
#  637.0,
#  661.5,
#  686.0,
#  710.5,
#  735.0,
#  759.5,
#  784.0,
#  808.5]

# %%
ENB2['Wall Area'].unique().tolist()
# Out:
# [294.0, 318.5, 343.0, 416.5, 245.0, 269.5, 367.5]

# %%
ENB2['Roof Area'].unique().tolist()
# Out:
# [110.25, 122.5, 147.0, 220.5]

# %%
ENB2['Overall Height'].unique().tolist()
# Out:
# [7.0, 3.5]

# %%
ENB2['Orientation'].unique().tolist()
# Out:
# [2, 3, 4, 5]

# %%
ENB2['Glazing Area'].unique().tolist()
# Out:
# [0.0, 0.1, 0.25, 0.4]

# %%
ENB2['Glazing Area Distribution'].unique().tolist()
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
ENB2.info() #get info about column datatypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
# Relative Compactness         768 non-null float64
# Surface Area                 768 non-null float64
# Wall Area                    768 non-null float64
# Roof Area                    768 non-null float64
# Overall Height               768 non-null float64
# Orientation                  768 non-null int64
# Glazing Area                 768 non-null float64
# Glazing Area Distribution    768 non-null int64
# Heating Load                 768 non-null float64
# Cooling Load                 768 non-null float64
# dtypes: float64(8), int64(2)
# memory usage: 60.1 KB

# %%
ENB2.shape #determine number of rows and columns
# Out:
# (768, 10)

# %% [markdown]
# Missing Values
# -

# %%
ENB2.isnull() #check for missing values in dataframe
# Out:
#      Relative Compactness  Surface Area  Wall Area  Roof Area  Overall Height  \
# 0                   False         False      False      False           False
# 1                   False         False      False      False           False
# 2                   False         False      False      False           False
# 3                   False         False      False      False           False
# 4                   False         False      False      False           False
# 5                   False         False      False      False           False
# 6                   False         False      False      False           False
# 7                   False         False      False      False           False
# 8                   False         False      False      False           False
# 9                   False         False      False      False           False
# 10                  False         False      False      False           False
# ...

# %%
ENB2.isnull().sum(axis=0) #since we cannot see all data, count number of missing values in columns
# Out:
# Relative Compactness         0
# Surface Area                 0
# Wall Area                    0
# Roof Area                    0
# Overall Height               0
# Orientation                  0
# Glazing Area                 0
# Glazing Area Distribution    0
# Heating Load                 0
# Cooling Load                 0
# dtype: int64

# %% [markdown]
# The above confirms that there are no missing data

# %% [markdown]
# Descriptive data
# -

# %%
ENB2.describe() #provide descriptive statistics
# Out:
#        Relative Compactness  Surface Area   Wall Area   Roof Area  \
# count            768.000000    768.000000  768.000000  768.000000
# mean               0.764167    671.708333  318.500000  176.604167
# std                0.105777     88.086116   43.626481   45.165950
# min                0.620000    514.500000  245.000000  110.250000
# 25%                0.682500    606.375000  294.000000  140.875000
# 50%                0.750000    673.750000  318.500000  183.750000
# 75%                0.830000    741.125000  343.000000  220.500000
# max                0.980000    808.500000  416.500000  220.500000
#
#        Overall Height  Orientation  Glazing Area  Glazing Area Distribution  \
# count       768.00000   768.000000    768.000000                  768.00000
# mean          5.25000     3.500000      0.234375                    2.81250
# std           1.75114     1.118763      0.133221                    1.55096
# ...

# %% [markdown]
# Check to see situation of Maximum and Minimum values

# %%
ENB2.loc[ENB2['Heating Load'] == 43.100000]
# Out:
#      Relative Compactness  Surface Area  Wall Area  Roof Area  Overall Height  \
# 593                  0.79         637.0      343.0      147.0             7.0
#
#      Orientation  Glazing Area  Glazing Area Distribution  Heating Load  \
# 593            3           0.4                          2          43.1
#
#      Cooling Load
# 593         39.41

# %%
ENB2.loc[ENB2['Heating Load'] == 6.010000]
# Out:
#     Relative Compactness  Surface Area  Wall Area  Roof Area  Overall Height  \
# 26                  0.74         686.0      245.0      220.5             3.5
#
#     Orientation  Glazing Area  Glazing Area Distribution  Heating Load  \
# 26            4           0.0                          0          6.01
#
#     Cooling Load
# 26         10.94

# %%
ENB2.loc[ENB2['Cooling Load'] == 48.030000]
# Out:
#      Relative Compactness  Surface Area  Wall Area  Roof Area  Overall Height  \
# 595                  0.79         637.0      343.0      147.0             7.0
#
#      Orientation  Glazing Area  Glazing Area Distribution  Heating Load  \
# 595            5           0.4                          2         41.92
#
#      Cooling Load
# 595         48.03

# %%
ENB2.loc[ENB2['Cooling Load'] == 10.900000]
# Out:
#     Relative Compactness  Surface Area  Wall Area  Roof Area  Overall Height  \
# 24                  0.74         686.0      245.0      220.5             3.5
#
#     Orientation  Glazing Area  Glazing Area Distribution  Heating Load  \
# 24            2           0.0                          0          6.07
#
#     Cooling Load
# 24          10.9

# %% [markdown]
# Distribution
# -

# %% [markdown]
# Visualise more descriptive statistics by plotting graphs.
#     Start with a bar graph (due to observation of data in columns)

# %%
import seaborn as sns

# %% [markdown]
# Visualize Heating and Cooling Loads Distribution

# %% [markdown]
# fig = plt.figure(figsize=(15, 6)) # figure for subplots
# ax1 = plt.subplot(1,2,1)  # 1 by 2 grid, first grid
# ax2 = plt.subplot(1,2,2) # 1 by 2 grid, second grid
# ENB2['Heating Load'].plot(kind='hist', ax=ax1)
# ax1.set_xlabel('The Heating Load of all 768 building shapes')
# ax1.set_title('Distribution of Heating Load', size = 20)
# ENB2['Cooling Load'].plot(kind='hist', ax=ax2, color = "red")
# ax2.set_xlabel('The Cooling Load of all 768 building shapes')
# ax2.set_title('Distribution of Cooling Load', size = 20)

# %% [markdown]
# Compare density of observations for Heating and Cooling Loads

# %%
fig = plt.figure(figsize=(15, 6))
sns.distplot(ENB2['Heating Load'])
sns.distplot(ENB2['Cooling Load'])
plt.title('Comparing Heating Load and Cooling Load Distribution', size = 20)
# Out:
# Text(0.5, 1.0, 'Comparing Heating Load and Cooling Load Distribution')

# %% [markdown]
# fig, ax = plt.subplots(figsize=(9,10))
# sns.boxplot(x='Overall Height', y='Heating Load', ENB2=ENB2)

# %%
fig, ax=plt.subplots(1,2) 
fig = plt.figure(figsize=(15, 6))
sns.boxplot(ENB2['Heating Load'], orient='v', showfliers=True, ax=ax[0]) #use seaborn to plot boxplot. showFliers to ensure outliers are displayed
sns.boxplot(ENB2['Cooling Load'], orient='v', showfliers=True, color='red', ax=ax[1])
ax[0].set_title('Distribution of Heating Load', size = 20)
ax[1].set_title('Distribution of Cooling Load', size = 20)
# Out:
# Text(0.5, 1.0, 'Distribution of Cooling Load')

# %% [markdown]
# See effect of independent variables (X1:X8) on dependent variables (Y1 & Y2)

# %%
sns.pairplot(ENB2)
plt.title('Distribution of all data', size = 20, y=2.30, x=0.005)
# Out:
# Text(0.005, 2.3, 'Distribution of all data')

# %% [markdown]
# Descriptive Statistics
# -
#
# After conducting Descriptive Summary Statistics on the data, the below are my observations:
#     1. The boxplots and histograms of the Heating and Cooling Loads look alike - both are right skewed (almost bimodal), with few outliers. Thus, the samples must be similar in their output data. This also means that the means are slightly larger than the medians
#     2. The largest number (approximately 177 of the 768 building shapes) have Heating Loads of 10 or 11 kwh. Fewer building shapes have high Heating and Cooling Loads.
#     3. The largest number (approximately 200 of the 768 building shapes) have Cooling loads of 10 or 11 kwh
#     4. The situation of Maximum value in Heating Load did not coincide with situation of maximum value in Cooling Load, but the minimum values were close enough
#     5. The maximum & minimum Overall Height & Glazing Area coincided with the maximum & minimum of the Heating Load.
#     6. The maximum Roof Area coincides with the minimum Heating Load and the minimum Cooling Load.
#     7. The coiniciding data for the minimum and maximum Heating Load and Cooling Load, all look alike. This ascertains the confirmation from the boxplots that there are no outliers.
#     8. We also have small standard deviations, showing very little variation in each column in the dataframe, and shows they are very close to the mean.
#     9. From the data information, there are:
#        * Dependent Variables - Heating Load, Cooling Load
#        * Independent/Explanatory Variables - Controlled (Overall Height, Orientation, Glazing Area), Manipulated (Wall Area, Roof Area, Surface Area, Relative Compactness)
#     10. The Roof Area data is skewed to the left
#     11.

# %% [markdown]
# Next Question 2.
# -

# %% [markdown]
# **Question 2.** Determine the average Relative Compactness, Surface Area, Wall Area, Roof Area, etc by the Orientation.

# %% [markdown]
# Average is the mean

# %%
ENB2.groupby(['Orientation']).mean()
# Out:
#              Relative Compactness  Surface Area  Wall Area   Roof Area  \
# Orientation
# 2                        0.764167    671.708333      318.5  176.604167
# 3                        0.764167    671.708333      318.5  176.604167
# 4                        0.764167    671.708333      318.5  176.604167
# 5                        0.764167    671.708333      318.5  176.604167
#
#              Overall Height  Glazing Area  Glazing Area Distribution  \
# Orientation
# 2                      5.25      0.234375                     2.8125
# 3                      5.25      0.234375                     2.8125
# 4                      5.25      0.234375                     2.8125
# 5                      5.25      0.234375                     2.8125
#
#              Heating Load  Cooling Load
# Orientation
# 2               22.312865     24.604531
# 3               22.380677     24.312552
# 4               22.259896     24.480312
# 5               22.275365     24.953646

# %%
plt.plot(ENB2.groupby(['Orientation']).mean())

# %%
sns.pointplot(ENB2.groupby(['Orientation']).mean())

# %% [markdown]
# NEXT QUESTION 3.
# -

# %% [markdown]
# ### Visualising the data

# %% [markdown]
# **Question 3.** To get a better understanding of the data, it helps to visualise the distributions in the data. Use the tools you've learned to display the distributions of the data. Please label your plots clearly and descriptively.

# %% [markdown]
# Show distributions of variables

# %% [markdown]
# Investigate the frequency distribution of the variables

# %%
df = ENB2[['Relative Compactness','Roof Area','Surface Area', 'Wall Area',]] #plot manipulated variables
df.plot.hist(subplots=True, layout=(2,2), figsize=(10, 10), bins=20)
plt.title('Manipulated Independent Data Distribution', size = 20, y=2.30, x=0.005)
# Out:
# Text(0.005, 2.3, 'Manipulated Independent Data Distribution')

# %%
fig = plt.figure(figsize=(10, 6))
RCax = ENB2['Relative Compactness'].value_counts().sort_index().plot.bar()
RCax.set_title('Relative Compactness Distribution', size = 20)
plt.xlabel('Value')
plt.ylabel('Frequency')
# Out:
# Text(0.5, 0, 'Frequency')

# %%
fig = plt.figure(figsize=(10, 6))
RAax = ENB2['Roof Area'].value_counts().sort_index().plot.bar()
RAax.set_title('Roof Area Distribution', size = 20)
RAax.set_xlabel('Value', size = 10)
plt.xlabel('Value')
plt.ylabel('Frequency')
# Out:
# Text(0.5, 0, 'Frequency')

# %%
fig = plt.figure(figsize=(10, 6))
SAax = ENB2['Surface Area'].value_counts().sort_index().plot.bar()
SAax.set_title('Surface Area Distribution', size = 20)
plt.xlabel('Value')
plt.ylabel('Frequency')
# Out:
# Text(0.5, 0, 'Frequency')

# %%
fig = plt.figure(figsize=(10, 6))
WAax = ENB2['Wall Area'].value_counts().sort_index().plot.bar()
WAax.set_title('Wall Area Distribution', size = 20)
plt.xlabel('Value')
plt.ylabel('Frequency')
# Out:
# Text(0.5, 0, 'Frequency')

# %%
fig = plt.figure(figsize=(10, 6))
WAax = ENB2['Glazing Area'].value_counts().sort_index().plot.bar()
WAax.set_title('Glazing Area Distribution using the Glazing Area variable', size = 20)
plt.xlabel('Value')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
fig = plt.figure(figsize=(10, 6))
ENB2['Cooling Load'].plot(kind='hist', color = "red")
plt.title('Cooling Load Distribution', size = 20)
plt.xlabel('Value')
# Out:
# Text(0.5, 0, 'Value')

# %%
fig = plt.figure(figsize=(10, 6))
ENB2['Heating Load'].plot(kind='hist', color = 'blue')
plt.title('Heating Load Distribution', size = 20)
plt.xlabel('Value')
# Out:
# Text(0.5, 0, 'Value')

# %% [markdown]
# There are outliers with the outputs, so the means are important

# %% [markdown]
# Investigate Spread of select independent variables with dependents

# %% [markdown]
# Starting with controlled independent variables

# %%
fig, ax=plt.subplots(1,2) 
sns.boxplot(x="Overall Height", y="Cooling Load", data=ENB2, color='blue', ax=ax[0]) #use seaborn to plot boxplot. showFliers to ensure outliers are displayed
sns.boxplot(x="Overall Height", y="Heating Load",  data=ENB2, color='red', ax=ax[1])
sns.swarmplot(x="Overall Height", y="Cooling Load", data=ENB2, ax=ax[0], size=3, color=".3", linewidth=0)
sns.swarmplot(x="Overall Height", y="Heating Load", data=ENB2, ax=ax[1], size=3, color=".3", linewidth=0)
ax[0].set_title('Cooling Load vs Overall Height', size = 16)
ax[1].set_title('Heating Load vs Overall Height', size = 16)
sns.set(rc={'figure.figsize':(10,10)})

# %%
fig, ax=plt.subplots(1,2) 
sns.boxplot(x="Orientation", y="Cooling Load", data=ENB2, color='blue', ax=ax[0]) #use seaborn to plot boxplot. showFliers to ensure outliers are displayed
sns.boxplot(x="Orientation", y="Heating Load",  data=ENB2, color='red', ax=ax[1])
sns.swarmplot(x="Orientation", y="Cooling Load", data=ENB2, ax=ax[0], size=3, color=".3", linewidth=0)
sns.swarmplot(x="Orientation", y="Heating Load", data=ENB2, ax=ax[1], size=3, color=".3", linewidth=0)
ax[0].set_title('Cooling Load vs Orientation', size = 16)
ax[1].set_title('Heating Load vs Orientation', size = 16)
sns.set(rc={'figure.figsize':(10,10)})

# %% [markdown]
# Now manipulated independent variables

# %%
fig, ax=plt.subplots(1,2) 
sns.boxplot(x="Roof Area", y="Cooling Load", data=ENB2, color='blue', ax=ax[0]) #use seaborn to plot boxplot. showFliers to ensure outliers are displayed
sns.boxplot(x="Roof Area", y="Heating Load",  data=ENB2, color='red', ax=ax[1])
sns.swarmplot(x="Roof Area", y="Cooling Load", data=ENB2, ax=ax[0], size=3, color=".3", linewidth=0)
sns.swarmplot(x="Roof Area", y="Heating Load", data=ENB2, ax=ax[1], size=3, color=".3", linewidth=0)
ax[0].set_title('Cooling Load vs Roof Area', size = 16)
ax[1].set_title('Heating Load vs Roof Area', size = 16)
sns.set(rc={'figure.figsize':(20,15)})

# %%
fig, ax=plt.subplots(1,2) 
sns.boxplot(x="Wall Area", y="Cooling Load", data=ENB2, color='blue', ax=ax[0]) #use seaborn to plot boxplot. showFliers to ensure outliers are displayed
sns.boxplot(x="Wall Area", y="Heating Load",  data=ENB2, color='red', ax=ax[1])
sns.swarmplot(x="Wall Area", y="Cooling Load", data=ENB2, ax=ax[0], size=3, color=".3", linewidth=0)
sns.swarmplot(x="Wall Area", y="Heating Load", data=ENB2, ax=ax[1], size=3, color=".3", linewidth=0)
ax[0].set_title('Cooling Load vs Wall Area', size = 16)
ax[1].set_title('Heating Load vs Wall Area', size = 16)
sns.set(rc={'figure.figsize':(20,10)})

# %% [markdown]
# See Heating Load vs Cooling Load distribution and relationship again

# %%
sns.pairplot(ENB2, vars=['Heating Load', 'Cooling Load'], 
            diag_kind='kde', 
             plot_kws={'alpha': 0.6, 's': 80, 'edgecolor': 'k'},
             height=4)

# Title 
plt.suptitle('Heating Load and Cooling Load', 
             size = 20, y=1.0)
# Out:
# Text(0.5, 1.0, 'Heating Load and Cooling Load')

# %% [markdown]
# Next Question
# -

# %% [markdown]
# **Question 4.** Relationships between variables. A scatterplot illustrates a linear relationship between two variables. Consider the  relationship between the dependent variables, `Y1` and `Y2,` and any of the other explanatory variables. Discuss what the relationships you observe. Plot appropriate visualisations and label your plots (title, axes labels, etc) with good descriptions.

# %% [markdown]
# Where Y1 = Heating Load
# and Y2 = Cooling Load

# %%
corr = ENB2.corr
corr
# Out:
#                            Relative Compactness  Surface Area     Wall Area  \
# Relative Compactness               1.000000e+00 -9.919015e-01 -2.037817e-01
# Surface Area                      -9.919015e-01  1.000000e+00  1.955016e-01
# Wall Area                         -2.037817e-01  1.955016e-01  1.000000e+00
# Roof Area                         -8.688234e-01  8.807195e-01 -2.923165e-01
# Overall Height                     8.277473e-01 -8.581477e-01  2.809757e-01
# Orientation                        0.000000e+00  0.000000e+00  0.000000e+00
# Glazing Area                       1.283986e-17  1.318356e-16 -7.969726e-19
# Glazing Area Distribution          1.764620e-17 -3.558613e-16  0.000000e+00
# Heating Load                       6.222722e-01 -6.581202e-01  4.556712e-01
# Cooling Load                       6.343391e-01 -6.729989e-01  4.271170e-01
#
#                               Roof Area  Overall Height  Orientation  \
# ...

# %%
sns.heatmap(corr) #add annot=True to show correlation values inside heatmap
plt.title('Correlation Heat Map of Variables', size=20)
# Out:
# Text(0.5, 1.0, 'Correlation Heat Map of Variables')

# %% [markdown]
# Going Deeper

# %% [markdown]
# Since Overall Height shows to have the highest correlation apart of all the independent variables, demarcate the data in Scatter Plots using Overall Height

# %% [markdown]
# But first, I'll plot Overall Height, then I'll plot the others in order of correlation, from the highest to the lowest

# %% [markdown]
# Positive Correlations

# %% [markdown]
# Overall Height

# %%
fig, ax =plt.subplots(1,2)
sns.scatterplot(x="Overall Height", y="Cooling Load", hue="Overall Height", data=ENB2, s=40, ax=ax[0])
sns.scatterplot(x="Overall Height", y="Heating Load", hue="Overall Height", data=ENB2, s=40, ax=ax[1], palette="Set1") #size="Orientation",
ax[0].set_title('Cooling vs Overall Height', size = 15)
ax[1].set_title('Heating vs Overall Height', size = 15)
sns.set(rc={'figure.figsize':(20,10)})
plt.suptitle('Overall Height', size=20, y=0.93)
# Out:
# Text(0.5, 0.93, 'Overall Height')

# %%
sns.lineplot(x='Overall Height', y='Cooling Load', data=ENB2, label='Cooling Load')
sns.lineplot(x='Overall Height', y='Heating Load', data=ENB2, label='Heating Load')
plt.title('Loads vs Overall Height', size = 20)
plt.ylabel('Load')
# Out:
# Text(0, 0.5, 'Load')

# %%
Now Relative Compactness

# %%
fig, ax =plt.subplots(1,2)
sns.scatterplot(x="Relative Compactness", y="Cooling Load", hue="Overall Height", data=ENB2, s=40, ax=ax[0])
sns.scatterplot(x="Relative Compactness", y="Heating Load", hue="Overall Height", data=ENB2, s=40, ax=ax[1], palette="Set1") #size="Orientation",
ax[0].set_title('Cooling vs Relative Compactness', size = 15)
ax[1].set_title('Heating vs Relative Compactness', size = 15)
sns.set(rc={'figure.figsize':(20,10)})
plt.suptitle('Relative Compactness', size=20, y=0.93)
# Out:
# Text(0.5, 0.93, 'Relative Compactness')

# %%
sns.lineplot(x="Relative Compactness", y="Heating Load", data=ENB2, label='Cooling Load')
sns.lineplot(x="Relative Compactness", y="Cooling Load", data=ENB2, label='Heating Load')
#Title
plt.title('Load vs Relative Compactness', size = 20)
plt.ylabel('Load')
# Out:
# Text(0, 0.5, 'Load')

# %% [markdown]
# Then Wall Area

# %%
fig, ax =plt.subplots(1,2)
sns.scatterplot(x="Wall Area", y="Cooling Load", hue="Overall Height", data=ENB2, s=40, ax=ax[0])
sns.scatterplot(x="Wall Area", y="Heating Load", hue="Overall Height", data=ENB2, s=40, ax=ax[1], palette="Set1") #size="Orientation",
ax[0].set_title('Cooling vs Wall Area', size = 15)
ax[1].set_title('Heating vs Wall Area', size = 15)
sns.set(rc={'figure.figsize':(20,10)})
plt.suptitle('Wall Area', size=20, y=0.93)
# Out:
# Text(0.5, 0.93, 'Wall Area')

# %%
sns.lineplot(x='Wall Area', y='Cooling Load', data=ENB2, label='Cooling Load')
sns.lineplot(x='Wall Area', y='Heating Load', data=ENB2, label='Heating Load')
plt.title('Loads vs Wall Area', size = 20)
plt.ylabel('Load')
# Out:
# Text(0, 0.5, 'Load')

# %% [markdown]
# Glazing Area

# %%
fig, ax =plt.subplots(1,2)
sns.scatterplot(x="Glazing Area", y="Cooling Load", hue="Overall Height", data=ENB2, s=40, ax=ax[0])
sns.scatterplot(x="Glazing Area", y="Heating Load", hue="Overall Height", data=ENB2, s=40, ax=ax[1], palette="Set1") #size="Orientation",
ax[0].set_title('Cooling vs Glazing Area', size = 15)
ax[1].set_title('Heating vs Glazing Area', size = 15)
sns.set(rc={'figure.figsize':(20,10)})
plt.suptitle('Glazing Area', size=20, y=0.93)
# Out:
# Text(0.5, 0.93, 'Glazing Area')

# %%
sns.lineplot(x="Glazing Area", y="Heating Load", data=ENB2, label='Cooling Load')
sns.lineplot(x="Glazing Area", y="Cooling Load", data=ENB2, label='Heating Load')
#Title
plt.title('Load vs Glazing Area', size = 20)
plt.ylabel('Load')
# Out:
# Text(0, 0.5, 'Load')

# %%
Zero Correlation

# %% [markdown]
# Glazing Area Distribution

# %%
fig, ax =plt.subplots(1,2)
sns.scatterplot(x="Glazing Area Distribution", y="Cooling Load", hue="Overall Height", data=ENB2, s=40, ax=ax[0])
sns.scatterplot(x="Glazing Area Distribution", y="Heating Load", hue="Overall Height", data=ENB2, s=40, ax=ax[1], palette="Set1") #size="Orientation",
ax[0].set_title('Cooling vs Glazing Area Distribution', size = 15)
ax[1].set_title('Heating vs Glazing Area Distribution', size = 15)
sns.set(rc={'figure.figsize':(20,10)})
plt.suptitle('Glazing Area Distribution', size=20, y=0.93)
# Out:
# Text(0.5, 0.93, 'Glazing Area Distribution')

# %%
sns.lineplot(x="Glazing Area Distribution", y="Heating Load", data=ENB2, label='Cooling Load')
sns.lineplot(x="Glazing Area Distribution", y="Cooling Load", data=ENB2, label='Heating Load')
#Title
plt.title('Load vs Glazing Area Distribution', size = 20)
plt.ylabel('Load')
# Out:
# Text(0, 0.5, 'Load')

# %%
Orientation

# %%
fig, ax =plt.subplots(1,2)
sns.scatterplot(x="Orientation", y="Cooling Load", hue="Overall Height", style="Orientation", data=ENB2, s=40, ax=ax[0])
sns.scatterplot(x="Orientation", y="Heating Load", hue="Overall Height", style="Orientation", data=ENB2, s=40, ax=ax[1], palette="Set1") #size="Orientation",
ax[0].set_title('Cooling vs Orientation', size = 15)
ax[1].set_title('Heating vs Orientation', size = 15)
sns.set(rc={'figure.figsize':(20,10)})
plt.suptitle('Orientation', size=20, y=0.93)
# Out:
# Text(0.5, 0.93, 'Orientation')

# %%
sns.lineplot(x="Orientation", y="Heating Load", data=ENB2, label='Cooling Load')
sns.lineplot(x="Orientation", y="Cooling Load", data=ENB2, label='Heating Load')
#Title
plt.title('Load vs Orientation', size = 20)
plt.ylabel('Load')
# Out:
# Text(0, 0.5, 'Load')

# %%
Negative Correlations

# %% [markdown]
# Now Surface Area

# %%
fig, ax =plt.subplots(1,2)
sns.scatterplot(x="Surface Area", y="Cooling Load", hue="Overall Height", style="Orientation", data=ENB2, s=40, ax=ax[0])
sns.scatterplot(x="Surface Area", y="Heating Load", hue="Overall Height", style="Orientation", data=ENB2, s=40, ax=ax[1], palette="Set1") #size="Orientation",
ax[0].set_title('Cooling vs Surface Area', size = 15)
ax[1].set_title('Heating vs Surface Area', size = 15)
sns.set(rc={'figure.figsize':(20,10)})
plt.suptitle('Surface Area', size=20, y=0.93)
# Out:
# Text(0.5, 0.93, 'Surface Area')

# %%
sns.lineplot(x='Surface Area', y='Cooling Load', data=ENB2, label='Cooling Load')
sns.lineplot(x='Surface Area', y='Heating Load', data=ENB2, label='Heating Load')
plt.title('Loads vs Surface Area', size = 20)
plt.ylabel('Load')
# Out:
# Text(0, 0.5, 'Load')

# %% [markdown]
# Roof Area

# %%
fig, ax =plt.subplots(1,2)
sns.scatterplot(x="Roof Area", y="Cooling Load", hue="Overall Height", style="Orientation", data=ENB2, s=40, ax=ax[0])
sns.scatterplot(x="Roof Area", y="Heating Load", hue="Overall Height", style="Orientation", data=ENB2, s=40, ax=ax[1], palette="Set1") #size="Orientation",
ax[0].set_title('Cooling vs Roof Area', size = 15)
ax[1].set_title('Heating vs Roof Area', size = 15)
sns.set(rc={'figure.figsize':(20,10)})
plt.suptitle('Roof Area', size=20, y=0.93)
# Out:
# Text(0.5, 0.93, 'Roof Area')

# %%
sns.lineplot(x='Roof Area', y='Cooling Load', data=ENB2, label='Cooling Load')
sns.lineplot(x='Roof Area', y='Heating Load', data=ENB2, label='Heating Load')
plt.title('Loads vs Roof Area', size = 20)
plt.ylabel('Load')
# Out:
# Text(0, 0.5, 'Load')

# %% [markdown]
# Relationships
# -
#
# From the line plots above, and confirmaing with the correlation heat map:
#     1. Roof Area and Surface Area have negative linear relationship with Heating Load and Cooling Load
#           * The Heating and Cooling Loads reduce as the Roof Area increases, after a peak at a Roof Area value of approximately 122.
#           * The Surface Area has quite a strange relationship with the Loads, and dips after a value of approximately 635
#     2. There is very very little correlation between the Heating Load & Cooling Load, and Orientation, Glazing Area, & also Glazing Area Distribution.
#           * The Heating Load takes a dip when the Orientation is 3, but increases thereafter, and the Cooling Load also experiences a decrease when the Orientation is 3, but is stable thereafter.
#           * The Heating and Cooling Loads are on a consistent increase with the Glazing Area, but is relatively stable after    a value of Glazing Are Distribution of 1.
#     3. There is a positive linear relationship between Relative Compactness, Wall Area, Overall Height, and the Heating and Cooling Loads
#           * The Overall Height is of an almost perfect linear relationship with the Heating and Cooling Loads
#           * The Heating and Cooling Loads experience a peak at a Relative Compactness value of approximately 0.78, but dips again after that, albeit, not at an alarming value
#           * The Heating and Cooling Loads experience their highest peak at the highest Wall Area value

# %% [markdown]
# **Question 5.** The orientation of a building can act as a categorical variable. Investigate how the Orientation variable affects the other variables.

# %% [markdown]
# Investigate Orientation (Independent Categorical Variable) effect on Cooling Load (Dependent Variable)
# -

# %%
ENB2.groupby(['Orientation']).count()
# Out:
#              Relative Compactness  Surface Area  Wall Area  Roof Area  \
# Orientation
# 2                             192           192        192        192
# 3                             192           192        192        192
# 4                             192           192        192        192
# 5                             192           192        192        192
#
#              Overall Height  Glazing Area  Glazing Area Distribution  \
# Orientation
# 2                       192           192                        192
# 3                       192           192                        192
# 4                       192           192                        192
# 5                       192           192                        192
#
#              Heating Load  Cooling Load
# Orientation
# 2                     192           192
# 3                     192           192
# 4                     192           192
# 5                     192           192

# %%
ENB2.groupby(['Orientation']).mean()
# Out:
#              Relative Compactness  Surface Area  Wall Area   Roof Area  \
# Orientation
# 2                        0.764167    671.708333      318.5  176.604167
# 3                        0.764167    671.708333      318.5  176.604167
# 4                        0.764167    671.708333      318.5  176.604167
# 5                        0.764167    671.708333      318.5  176.604167
#
#              Overall Height  Glazing Area  Glazing Area Distribution  \
# Orientation
# 2                      5.25      0.234375                     2.8125
# 3                      5.25      0.234375                     2.8125
# 4                      5.25      0.234375                     2.8125
# 5                      5.25      0.234375                     2.8125
#
#              Heating Load  Cooling Load
# Orientation
# 2               22.312865     24.604531
# 3               22.380677     24.312552
# 4               22.259896     24.480312
# 5               22.275365     24.953646

# %% [markdown]
# I'll be investigating how it affects one dependent variable, one controlled independent variable, and one manipulative independent variable. I'll be referencing my correlation heatmap

# %% [markdown]
# fig, ax =plt.subplots(1,2)
# sns.scatterplot(x="Orientation", y="Cooling Load", hue="Overall Height", style="Orientation", data=ENB2, s=40, ax=ax[0])
# sns.scatterplot(x="Orientation", y="Heating Load", hue="Overall Height", style="Orientation", data=ENB2, s=40, ax=ax[1], palette="Set1") #size="Orientation",
# ax[0].set_title('Cooling vs Orientation', size = 15)
# ax[1].set_title('Heating vs Orientation', size = 15)
# sns.set(rc={'figure.figsize':(20,10)})
# plt.suptitle('Cooling Load', size=20, y=0.93)

# %%
corr = ENB2.corr()
corr
# Out:
#                            Relative Compactness  Surface Area     Wall Area  \
# Relative Compactness               1.000000e+00 -9.919015e-01 -2.037817e-01
# Surface Area                      -9.919015e-01  1.000000e+00  1.955016e-01
# Wall Area                         -2.037817e-01  1.955016e-01  1.000000e+00
# Roof Area                         -8.688234e-01  8.807195e-01 -2.923165e-01
# Overall Height                     8.277473e-01 -8.581477e-01  2.809757e-01
# Orientation                        0.000000e+00  0.000000e+00  0.000000e+00
# Glazing Area                       1.283986e-17  1.318356e-16 -7.969726e-19
# Glazing Area Distribution          1.764620e-17 -3.558613e-16  0.000000e+00
# Heating Load                       6.222722e-01 -6.581202e-01  4.556712e-01
# Cooling Load                       6.343391e-01 -6.729989e-01  4.271170e-01
#
#                               Roof Area  Overall Height  Orientation  \
# ...

# %%
sns.heatmap(corr)
plt.title('Correlation Heat Map of Variables', size=20)
# Out:
# Text(0.5, 1.0, 'Correlation Heat Map of Variables')

# %% [markdown]
# Cooling Load
# -

# %%
ENB2['Cooling Load'].mean()
# Out:
# 24.58776041666671

# %%
Div = ENB2.loc[ENB2['Cooling Load'] < 24.58776041666671]
Div
# Out:
#      Relative Compactness  Surface Area  Wall Area  Roof Area  Overall Height  \
# 0                    0.98         514.5      294.0     110.25             7.0
# 1                    0.98         514.5      294.0     110.25             7.0
# 2                    0.98         514.5      294.0     110.25             7.0
# 3                    0.98         514.5      294.0     110.25             7.0
# 9                    0.86         588.0      294.0     147.00             7.0
# 10                   0.86         588.0      294.0     147.00             7.0
# 12                   0.82         612.5      318.5     147.00             7.0
# 13                   0.82         612.5      318.5     147.00             7.0
# 14                   0.82         612.5      318.5     147.00             7.0
# 24                   0.74         686.0      245.0     220.50             3.5
# 25                   0.74         686.0      245.0     220.50             3.5
# ...

# %%
fig = plt.figure(figsize=(10, 6))
Div['Cooling Load'].plot(kind='hist', color = "red")
plt.title('Cooling Load Distribution', size = 20)

#sns.lineplot(x="Orientation", y="Heating Load", data=ENB2)
#ENB2.plot(x="Orientation", y="Cooling Load", data=ENB2[ENB2['Cooling Load']], color='k', label='Sine')
# Out:
# Text(0.5, 1.0, 'Cooling Load Distribution')

# %%
sns.scatterplot(x="Orientation", y="Cooling Load", data=Div, palette='Set1',)

# %%
fig = plt.figure(figsize=(20, 10))
sns.swarmplot(x="Orientation", y="Cooling Load", data=Div, color=".25")
sns.barplot(x="Orientation", y="Cooling Load", data=Div)
plt.title('Cooling Load Distribution by Orientation  - Bar and Swarmplot', size = 25)
# Out:
# C:\Users\acer\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5, 1.0, 'Cooling Load Distribution by Orientation  - Bar and Swarmplot')

# %% [markdown]
# I know the bar values are computed based on mean in my case (the default option), and I assume the error bars are computed based on a Normal distribution 95% confidence interval.

# %%
sns.pointplot(x='Orientation', y='Cooling Load', data=ENB2)#plot means of Cooling Load against Orientation
plt.title('Cooling Load vs Orientation', size = 20)
# Out:
# C:\Users\acer\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5, 1.0, 'Cooling Load vs Orientation')

# %% [markdown]
# sns.pairplot(ENB2, hue = 'Orientation')

# %% [markdown]
# Investigate frequency of Orientation in samples

# %%
sns.countplot(ENB2['Orientation'])

# %% [markdown]
# Investigate distribution of Orientation with mean

# %%
ENB2.groupby(['Orientation']).mean()

# %% [markdown]
# Investigate distribution of Orientation with median

# %%
ENB2.groupby(['Orientation']).median()

# %%
sns.set(style="ticks", color_codes=True)

g = sns.FacetGrid(ENB2, col="Orientation")
g = g.map(plt.hist, "Heating Load")

# %%
g = sns.FacetGrid(ENB2, col="Orientation",  row="Overall Height")
g = g.map(plt.scatter, "Heating Load", "Cooling Load", edgecolor="w")

# %%
g = sns.FacetGrid(ENB2, col="Orientation")
g = g.map(plt.scatter, "Heating Load", "Overall Height", edgecolor="w")

# %%
sns.histplot(x="Orientation", y="Heating Load", hue = "Orientation", data=ENB2, s=40)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-183-80ab132c2876> in <module>
# ----> 1 sns.histplot(x="Orientation", y="Heating Load", hue = "Orientation", data=ENB2, s=40)
#
# AttributeError: module 'seaborn' has no attribute 'histplot'

# %%
x = ENB2.loc[ENB2["Orientation"]]
s = [20*2**n for n in range(len(x))]
sns.scatterplot(x="Orientation", y="Cooling Load", data=ENB2, palette='Set1',)

# %%
sns.scatterplot(x="Orientation", y="Heating Load", hue = "Orientation", data=ENB2, s=50, style="Overall Height")

# %%
sns.scatterplot(x="Heating Load", y="Cooling Load", hue = "Orientation", data=ENB2, s=40)
sns.set(rc={'figure.figsize':(10,20)})
plt.suptitle('Heating Load vs Cooling Load', 
             size = 20)

# %% [markdown]
# ENB_output = ENB2[ENB2['Orientation']==2]

# %% [markdown]
# height = 3.5
# fig = plt.figure(figsize=(15,4))
# plot_data = ENB_output[ENB_output['Overall Height']==height]
# plt.plot(plot_data['Glazing Area'],plot_data['Heating Load'],color = "green")
# plt.title(current)
# plt.xticks(rotation=90);
